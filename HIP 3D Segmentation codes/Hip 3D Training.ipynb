# %%
import nrrd
import os
import pandas as pd
import numpy as np
from scipy.ndimage import zoom
import csv
import matplotlib.pyplot as plt
from glob import glob
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, concatenate, add, Conv3DTranspose, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow.keras import backend as K
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model, save_model
from matplotlib.colors import ListedColormap
#import Segment_support_lib

# %%
crop_hip_train = 'F:\\Birva_Harsh\\Hip_Crop_Data\\train\\Hip'
crop_mask_train = 'F:\\Birva_Harsh\\Hip_Crop_Data\\train\\Mask'
crop_hip_test = 'F:\\Birva_Harsh\\Hip_Crop_Data\\test\\Hip'
crop_mask_test = 'F:\\Birva_Harsh\\Hip_Crop_Data\\test\\Mask'

# %%
hip_train = [os.path.join(crop_hip_train, i) for i in os.listdir(crop_hip_train)]
mask_train = [path.replace('\\Hip\\', '\\Mask\\') for path in hip_train]

hip_test = [os.path.join(crop_hip_test, i) for i in os.listdir(crop_hip_test)]
mask_test = [path.replace('\\Hip\\', '\\Mask\\') for path in hip_test]

# %%
df_train = pd.DataFrame( data = {
    'hip': hip_train,
    'mask': mask_train
})

df_test = pd.DataFrame( data = {
    'hip': hip_test,
    'mask': mask_test
})

# %%
def load_and_preprocess_image(file_path,resize):
    img,info = nrrd.read(file_path)
    if resize == 128:
        img = img[::2,::2,::2]
    img = np.clip(img, a_min=-1024, a_max=None)
    img = img[:,:,:,np.newaxis]   
    img_scaled = img.astype(np.float32) / 1024.0
    return img_scaled

# %%
def load_and_preprocess_mask(mask_path,img_path,resize):
    img,hinfo = nrrd.read(img_path)
    mask,minfo = nrrd.read(mask_path)
    
    if resize == 128:
        img = img[::2,::2,::2]
        mask = mask[::2,::2,::2]
        
    thres = np.where(img < 200, 0, 1)
    res = thres-mask
    res = np.where(res<=0,0,1)
    
    mask = np.stack((mask,res), axis=-1)
    mask = mask.astype(np.float32)
    
    return mask

# %%
def generate_data_generator(dataframe,resize, batch_size=1):
    num_samples = len(dataframe)
    while True:
        indices = np.random.randint(0, num_samples, batch_size)
        batch_hip = []
        batch_mask = []
        for idx in indices:
            hip_img = load_and_preprocess_image(dataframe.iloc[idx]['hip'],resize)
            mask_img = load_and_preprocess_mask(dataframe.iloc[idx]['mask'],dataframe.iloc[idx]['hip'],resize)
            batch_hip.append(hip_img)
            batch_mask.append(mask_img)
        batch_hip = np.array(batch_hip)
        batch_mask = np.array(batch_mask)
        
        yield batch_hip, batch_mask

# %%
batch_size = 1
train_generator = generate_data_generator(df_train, batch_size=batch_size,resize=256)
test_generator = generate_data_generator(df_test, batch_size=batch_size,resize=256)

# %%
def dice_coeff(y_true, y_pred, smooth=100):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)

    intersection = K.sum(y_true_flatten * y_pred_flatten)
    union = K.sum(y_true_flatten) + K.sum(y_pred_flatten)
    return (2 * intersection + smooth) / (union + smooth)

def dice_coeff_loss(y_true, y_pred, smooth=100):
    return 1 - dice_coeff(y_true, y_pred, smooth)

# %%
def DICE_COE(mask1, mask2):
    intersect = np.sum(mask1*mask2)
    fsum = np.sum(mask1)
    ssum = np.sum(mask2)
    dice = (2 * intersect ) / (fsum + ssum)
    dice = np.mean(dice)
    dice = round(dice, 3)
    return dice

# %%
def encoder_block(inputs, filters):
    conv = Conv3D(filters, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(inputs)
    conv = Conv3D(filters, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(conv)
    x = BatchNormalization()(conv)
    pool = MaxPooling3D(pool_size=(2,2,2), padding="same")(x)
    
    return pool,x

def decoder_block(inputs, filters, x):
    up = Conv3DTranspose(filters, kernel_size=(3,3,3), strides=(2, 2, 2), padding="same", kernel_initializer='he_uniform')(inputs)
    con = concatenate([up, x])
    conv = Conv3D(filters, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(con)
    conv = Conv3D(filters, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(conv)
    x = BatchNormalization()(conv)
    
    return x

# %% [markdown]
# # Pocket Net

# %%
f = 16

# %%
def Pocketnet_16(input_shape = (None, None, None, 1)):
    inputs = Input(input_shape)
    x = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(inputs)
    x = BatchNormalization()(x)
    
    b1,c1 = encoder_block(x, f)
    b2,c2 = encoder_block(b1, f*2)
    b3,c3 = encoder_block(b2, f*2)
    b4,c4 = encoder_block(b3, f*2)

    conv = Conv3D(f*2, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(b4)
    conv = Conv3D(f*2, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(conv)

    b4 = decoder_block(conv, f*2, c4)
    b5 = decoder_block(b4, f*2, c3)
    b6 = decoder_block(b5, f*2, c2)
    b7 = decoder_block(b6, f, c1)
    
    outputs = Conv3D(filters = 2, kernel_size = (1,1,1), activation = "sigmoid")(b7)
    
    return Model(inputs=[inputs], outputs = [outputs])

# %%
filepath = "F:\\Birva_Harsh\\Hip_models\\pocketnet_256_32_new.keras"

checkpoint = ModelCheckpoint(filepath, 
                             verbose=1 
                             )

# %%
pocket_16 = Pocketnet_16(input_shape = (None,None,None,1))
pocket_16.compile(optimizer='adam', loss=dice_coeff_loss, metrics=[dice_coeff])

# %%
epochs = 50

# %%
history = pocket_16.fit(
        train_generator,
        steps_per_epoch=len(df_train) // batch_size,
        epochs=epochs,
        callbacks=[checkpoint],
        validation_data=test_generator,
        validation_steps=len(df_test) // batch_size
    )

# %% [markdown]
# # Half U-Net

# %%
f = 16

# %%
def Unet_8(input_shape = (None, None, None, 1)):
    inputs = Input(input_shape)
    x = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(inputs)
    x = BatchNormalization()(x)
    
    b1,c1 = encoder_block(x, f)
    b2,c2 = encoder_block(b1, f)
    b3,c3 = encoder_block(b2, f*2)
    b4,c4 = encoder_block(b3, f*2)

    conv = Conv3D(f*4, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(b4)
    conv = Conv3D(f*4, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(conv)

    b4 = decoder_block(conv, f*2, c4)
    b5 = decoder_block(b4, f*2, c3)
    b6 = decoder_block(b5, f, c2)
    b7 = decoder_block(b6, f, c1)
    
    outputs = Conv3D(filters = 2, kernel_size = (1,1,1), activation = "sigmoid")(b7)
    
    return Model(inputs=[inputs], outputs = [outputs])

# %%
filepath = "F:\\Birva_Harsh\\Hip_models\\new_unet_256_8.keras"

checkpoint = ModelCheckpoint(filepath, 
                             verbose=1 
                             )

# %%
unet_8 = Unet_8(input_shape = (None,None,None,1))
unet_8.compile(optimizer='adam', loss=dice_coeff_loss, metrics=[dice_coeff])

# %%
epochs = 50

# %%
history = unet_8.fit(
        train_generator,
        steps_per_epoch=len(df_train) // batch_size,
        epochs=epochs,
        callbacks=[checkpoint],
        validation_data=test_generator,
        validation_steps=len(df_test) // batch_size
    )

# %%
unet_8.summary()

# %% [markdown]
# # U-Net

# %%
f = 8

# %%
def Unet_8(input_shape = (None, None, None, 1)):
    inputs = Input(input_shape)
    x = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(inputs)
    x = BatchNormalization()(x)
    
    b1,c1 = encoder_block(x, f)
    b2,c2 = encoder_block(b1, f*2)
    b3,c3 = encoder_block(b2, f*4)
    b4,c4 = encoder_block(b3, f*8)

    conv = Conv3D(f*8, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(b4)
    conv = Conv3D(f*8, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(conv)

    b4 = decoder_block(conv, f*8, c4)
    b5 = decoder_block(b4, f*4, c3)
    b6 = decoder_block(b5, f*2, c2)
    b7 = decoder_block(b6, f, c1)
    
    outputs = Conv3D(filters = 2, kernel_size = (1,1,1), activation = "sigmoid")(b7)
    
    return Model(inputs=[inputs], outputs = [outputs])

# %%
filepath = "F:\\Birva_Harsh\\Hip_models\\unet_256_8.keras"

checkpoint = ModelCheckpoint(filepath, 
                             verbose=1 
                             )

# %%
unet_8 = Unet_8(input_shape = (None,None,None,1))
unet_8.compile(optimizer='adam', loss=dice_coeff_loss, metrics=[dice_coeff])

# %%
epochs = 50

# %%
history = unet_8.fit(
        train_generator,
        steps_per_epoch=len(df_train) // batch_size,
        epochs=epochs,
        callbacks=[checkpoint],
        validation_data=test_generator,
        validation_steps=len(df_test) // batch_size
    )

# %% [markdown]
# # Resnet Type Net (Filters=16)

# %%
def encoder_block(inputs, f):
    conv = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(inputs)
    conv = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(conv)
    pool = MaxPooling3D(pool_size=(2,2,2), padding="same")(conv)

    return pool,conv

def decoder_block(inputs, f, x):
    up = Conv3DTranspose(f, kernel_size=(3,3,3), strides=(2, 2, 2), padding="same", kernel_initializer='he_uniform')(inputs)
    conv = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(up)
    conv = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(conv)

    if x is not None:
        x = BatchNormalization()(x)
        conv = BatchNormalization()(conv)
        conv = add([x, conv])

    return conv

# %%
def u_block(inputs, f):
    b1,c1 = encoder_block(inputs, f)
    b2,c2 = encoder_block(b1, f)

    conv = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(b2)
    conv = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(conv)

    b4 = decoder_block(conv, f,None)
    b5 = decoder_block(b4, f, c1)

    return b5

# %%
f = 8
num_blocks = 4

# %%
def res_type_16(input_shape = (None, None, None, 1)):

    inputs = Input(input_shape)
    x = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(inputs)
    x = BatchNormalization()(x)

    for i in range(num_blocks):
        x = u_block(x,f)
        b = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(inputs)
        b = BatchNormalization()(b)
        x = add([x, b])
    
    outputs = Conv3D(filters = 2, kernel_size = (1,1,1), activation = "sigmoid")(x)
    
    return Model(inputs=[inputs], outputs = [outputs])

# %%
epochs=50

# %%
filepath = "F:\\Birva_Harsh\\Hip_models\\restype_8.keras"

checkpoint = ModelCheckpoint(filepath, 
                             verbose=1 
                             )
# Out:
# 75/75 [==============================] - ETA: 0s - loss: 0.0963 - dice_coeff: 0.9037
# Epoch 46: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-2.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0963 - dice_coeff: 0.9037 - val_loss: 0.1187 - val_dice_coeff: 0.8813
# Epoch 47/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0962 - dice_coeff: 0.9038
# Epoch 47: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-2.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0962 - dice_coeff: 0.9038 - val_loss: 0.1201 - val_dice_coeff: 0.8799
# Epoch 48/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0938 - dice_coeff: 0.9062
# Epoch 48: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-2.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0938 - dice_coeff: 0.9062 - val_loss: 0.1128 - val_dice_coeff: 0.8872
# Epoch 49/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0962 - dice_coeff: 0.9038
# Epoch 49: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-2.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0962 - dice_coeff: 0.9038 - val_loss: 0.1472 - val_dice_coeff: 0.8528
# Epoch 50/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0946 - dice_coeff: 0.9054
# Epoch 50: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-2.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0946 - dice_coeff: 0.9054 - val_loss: 0.1172 - val_dice_coeff: 0.8828
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# Epoch 1/50
# 75/75 [==============================] - ETA: 0s - loss: 0.5749 - dice_coeff: 0.4251
# Epoch 1: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 110s 1s/step - loss: 0.5749 - dice_coeff: 0.4251 - val_loss: 0.9793 - val_dice_coeff: 0.0207
# Epoch 2/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2726 - dice_coeff: 0.7274
# Epoch 2: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.2726 - dice_coeff: 0.7274 - val_loss: 0.9976 - val_dice_coeff: 0.0024
# Epoch 3/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2105 - dice_coeff: 0.7895
# Epoch 3: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.2105 - dice_coeff: 0.7895 - val_loss: 0.9937 - val_dice_coeff: 0.0063
# Epoch 4/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1719 - dice_coeff: 0.8281
# Epoch 4: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 108s 1s/step - loss: 0.1719 - dice_coeff: 0.8281 - val_loss: 0.9697 - val_dice_coeff: 0.0303
# Epoch 5/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1434 - dice_coeff: 0.8566
# Epoch 5: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 108s 1s/step - loss: 0.1434 - dice_coeff: 0.8566 - val_loss: 0.8134 - val_dice_coeff: 0.1866
# Epoch 6/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1350 - dice_coeff: 0.8650
# Epoch 6: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 108s 1s/step - loss: 0.1350 - dice_coeff: 0.8650 - val_loss: 0.5912 - val_dice_coeff: 0.4088
# Epoch 7/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1237 - dice_coeff: 0.8763
# Epoch 7: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 121s 2s/step - loss: 0.1237 - dice_coeff: 0.8763 - val_loss: 0.2429 - val_dice_coeff: 0.7571
# Epoch 8/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1199 - dice_coeff: 0.8801
# Epoch 8: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 109s 1s/step - loss: 0.1199 - dice_coeff: 0.8801 - val_loss: 0.1905 - val_dice_coeff: 0.8095
# Epoch 9/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1162 - dice_coeff: 0.8838
# Epoch 9: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1162 - dice_coeff: 0.8838 - val_loss: 0.1548 - val_dice_coeff: 0.8452
# Epoch 10/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1174 - dice_coeff: 0.8826
# Epoch 10: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1174 - dice_coeff: 0.8826 - val_loss: 0.1790 - val_dice_coeff: 0.8210
# Epoch 11/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1142 - dice_coeff: 0.8858
# Epoch 11: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 108s 1s/step - loss: 0.1142 - dice_coeff: 0.8858 - val_loss: 0.1455 - val_dice_coeff: 0.8545
# Epoch 12/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1092 - dice_coeff: 0.8908
# Epoch 12: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1092 - dice_coeff: 0.8908 - val_loss: 0.1260 - val_dice_coeff: 0.8740
# Epoch 13/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1079 - dice_coeff: 0.8921
# Epoch 13: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 119s 2s/step - loss: 0.1079 - dice_coeff: 0.8921 - val_loss: 0.1293 - val_dice_coeff: 0.8707
# Epoch 14/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1068 - dice_coeff: 0.8932
# Epoch 14: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1068 - dice_coeff: 0.8932 - val_loss: 0.1425 - val_dice_coeff: 0.8575
# Epoch 15/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1033 - dice_coeff: 0.8967
# Epoch 15: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.1033 - dice_coeff: 0.8967 - val_loss: 0.1393 - val_dice_coeff: 0.8607
# Epoch 16/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1025 - dice_coeff: 0.8975
# Epoch 16: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.1025 - dice_coeff: 0.8975 - val_loss: 0.1204 - val_dice_coeff: 0.8796
# Epoch 17/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1037 - dice_coeff: 0.8963
# Epoch 17: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1037 - dice_coeff: 0.8963 - val_loss: 0.1207 - val_dice_coeff: 0.8793
# Epoch 18/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1057 - dice_coeff: 0.8943
# Epoch 18: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 119s 2s/step - loss: 0.1057 - dice_coeff: 0.8943 - val_loss: 0.1520 - val_dice_coeff: 0.8480
# Epoch 19/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1013 - dice_coeff: 0.8987
# Epoch 19: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1013 - dice_coeff: 0.8987 - val_loss: 0.1257 - val_dice_coeff: 0.8743
# Epoch 20/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0994 - dice_coeff: 0.9006
# Epoch 20: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0994 - dice_coeff: 0.9006 - val_loss: 0.1191 - val_dice_coeff: 0.8809
# Epoch 21/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1026 - dice_coeff: 0.8974
# Epoch 21: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.1026 - dice_coeff: 0.8974 - val_loss: 0.1275 - val_dice_coeff: 0.8725
# Epoch 22/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0973 - dice_coeff: 0.9027
# Epoch 22: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0973 - dice_coeff: 0.9027 - val_loss: 0.1157 - val_dice_coeff: 0.8843
# Epoch 23/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1021 - dice_coeff: 0.8979
# Epoch 23: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.1021 - dice_coeff: 0.8979 - val_loss: 0.1152 - val_dice_coeff: 0.8848
# Epoch 24/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0965 - dice_coeff: 0.9035
# Epoch 24: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0965 - dice_coeff: 0.9035 - val_loss: 0.1223 - val_dice_coeff: 0.8777
# Epoch 25/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1008 - dice_coeff: 0.8992
# Epoch 25: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1008 - dice_coeff: 0.8992 - val_loss: 0.1373 - val_dice_coeff: 0.8627
# Epoch 26/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0988 - dice_coeff: 0.9012
# Epoch 26: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0988 - dice_coeff: 0.9012 - val_loss: 0.1174 - val_dice_coeff: 0.8826
# Epoch 27/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0971 - dice_coeff: 0.9029
# Epoch 27: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0971 - dice_coeff: 0.9029 - val_loss: 0.1256 - val_dice_coeff: 0.8744
# Epoch 28/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0999 - dice_coeff: 0.9001
# Epoch 28: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 119s 2s/step - loss: 0.0999 - dice_coeff: 0.9001 - val_loss: 0.1219 - val_dice_coeff: 0.8781
# Epoch 29/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0983 - dice_coeff: 0.9017
# Epoch 29: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0983 - dice_coeff: 0.9017 - val_loss: 0.1348 - val_dice_coeff: 0.8652
# Epoch 30/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0960 - dice_coeff: 0.9040
# Epoch 30: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0960 - dice_coeff: 0.9040 - val_loss: 0.1122 - val_dice_coeff: 0.8878
# Epoch 31/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0937 - dice_coeff: 0.9063
# Epoch 31: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0937 - dice_coeff: 0.9063 - val_loss: 0.1142 - val_dice_coeff: 0.8858
# Epoch 32/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1000 - dice_coeff: 0.9000
# Epoch 32: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.1000 - dice_coeff: 0.9000 - val_loss: 0.1138 - val_dice_coeff: 0.8862
# Epoch 33/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0941 - dice_coeff: 0.9059
# Epoch 33: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0941 - dice_coeff: 0.9059 - val_loss: 0.1205 - val_dice_coeff: 0.8795
# Epoch 34/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0921 - dice_coeff: 0.9079
# Epoch 34: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0921 - dice_coeff: 0.9079 - val_loss: 0.1236 - val_dice_coeff: 0.8764
# Epoch 35/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0987 - dice_coeff: 0.9013
# Epoch 35: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0987 - dice_coeff: 0.9013 - val_loss: 0.1435 - val_dice_coeff: 0.8565
# Epoch 36/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0945 - dice_coeff: 0.9055
# Epoch 36: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.0945 - dice_coeff: 0.9055 - val_loss: 0.1463 - val_dice_coeff: 0.8537
# Epoch 37/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0923 - dice_coeff: 0.9078
# Epoch 37: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0923 - dice_coeff: 0.9078 - val_loss: 0.1272 - val_dice_coeff: 0.8728
# Epoch 38/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0964 - dice_coeff: 0.9036
# Epoch 38: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0964 - dice_coeff: 0.9036 - val_loss: 0.1159 - val_dice_coeff: 0.8841
# Epoch 39/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0942 - dice_coeff: 0.9058
# Epoch 39: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.0942 - dice_coeff: 0.9058 - val_loss: 0.1274 - val_dice_coeff: 0.8726
# Epoch 40/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0920 - dice_coeff: 0.9080
# Epoch 40: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0920 - dice_coeff: 0.9080 - val_loss: 0.1165 - val_dice_coeff: 0.8835
# Epoch 41/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0955 - dice_coeff: 0.9045
# Epoch 41: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0955 - dice_coeff: 0.9045 - val_loss: 0.1135 - val_dice_coeff: 0.8865
# Epoch 42/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0954 - dice_coeff: 0.9046
# Epoch 42: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0954 - dice_coeff: 0.9046 - val_loss: 0.1253 - val_dice_coeff: 0.8747
# Epoch 43/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0893 - dice_coeff: 0.9107
# Epoch 43: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0893 - dice_coeff: 0.9107 - val_loss: 0.1099 - val_dice_coeff: 0.8901
# Epoch 44/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0934 - dice_coeff: 0.9066
# Epoch 44: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0934 - dice_coeff: 0.9066 - val_loss: 0.1168 - val_dice_coeff: 0.8832
# Epoch 45/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0904 - dice_coeff: 0.9096
# Epoch 45: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0904 - dice_coeff: 0.9096 - val_loss: 0.1245 - val_dice_coeff: 0.8755
# Epoch 46/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0902 - dice_coeff: 0.9098
# Epoch 46: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0902 - dice_coeff: 0.9098 - val_loss: 0.1175 - val_dice_coeff: 0.8825
# Epoch 47/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0883 - dice_coeff: 0.9117
# Epoch 47: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0883 - dice_coeff: 0.9117 - val_loss: 0.1164 - val_dice_coeff: 0.8836
# Epoch 48/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0894 - dice_coeff: 0.9106
# Epoch 48: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0894 - dice_coeff: 0.9106 - val_loss: 0.1143 - val_dice_coeff: 0.8857
# Epoch 49/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0910 - dice_coeff: 0.9090
# Epoch 49: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0910 - dice_coeff: 0.9090 - val_loss: 0.1262 - val_dice_coeff: 0.8738
# Epoch 50/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0935 - dice_coeff: 0.9065
# Epoch 50: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-3.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0935 - dice_coeff: 0.9065 - val_loss: 0.1147 - val_dice_coeff: 0.8853
# 1/1 [==============================] - 1s 522ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# Epoch 1/50
# 75/75 [==============================] - ETA: 0s - loss: 0.6819 - dice_coeff: 0.3181
# Epoch 1: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 110s 1s/step - loss: 0.6819 - dice_coeff: 0.3181 - val_loss: 0.9946 - val_dice_coeff: 0.0054
# Epoch 2/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3304 - dice_coeff: 0.6696
# Epoch 2: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.3304 - dice_coeff: 0.6696 - val_loss: 0.9993 - val_dice_coeff: 6.8060e-04
# Epoch 3/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2129 - dice_coeff: 0.7871
# Epoch 3: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.2129 - dice_coeff: 0.7871 - val_loss: 0.9956 - val_dice_coeff: 0.0044
# Epoch 4/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1633 - dice_coeff: 0.8367
# Epoch 4: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1633 - dice_coeff: 0.8367 - val_loss: 0.9441 - val_dice_coeff: 0.0559
# Epoch 5/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1412 - dice_coeff: 0.8588
# Epoch 5: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.1412 - dice_coeff: 0.8588 - val_loss: 0.7585 - val_dice_coeff: 0.2415
# Epoch 6/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1301 - dice_coeff: 0.8699
# Epoch 6: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 119s 2s/step - loss: 0.1301 - dice_coeff: 0.8699 - val_loss: 0.4626 - val_dice_coeff: 0.5374
# Epoch 7/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1243 - dice_coeff: 0.8757
# Epoch 7: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.1243 - dice_coeff: 0.8757 - val_loss: 0.2078 - val_dice_coeff: 0.7922
# Epoch 8/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1167 - dice_coeff: 0.8833
# Epoch 8: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1167 - dice_coeff: 0.8833 - val_loss: 0.3551 - val_dice_coeff: 0.6449
# Epoch 9/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1202 - dice_coeff: 0.8798
# Epoch 9: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 119s 2s/step - loss: 0.1202 - dice_coeff: 0.8798 - val_loss: 0.2473 - val_dice_coeff: 0.7527
# Epoch 10/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1121 - dice_coeff: 0.8879
# Epoch 10: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 119s 2s/step - loss: 0.1121 - dice_coeff: 0.8879 - val_loss: 0.1470 - val_dice_coeff: 0.8530
# Epoch 11/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1111 - dice_coeff: 0.8889
# Epoch 11: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 108s 1s/step - loss: 0.1111 - dice_coeff: 0.8889 - val_loss: 0.1493 - val_dice_coeff: 0.8507
# Epoch 12/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1092 - dice_coeff: 0.8908
# Epoch 12: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1092 - dice_coeff: 0.8908 - val_loss: 0.1412 - val_dice_coeff: 0.8588
# Epoch 13/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1093 - dice_coeff: 0.8907
# Epoch 13: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.1093 - dice_coeff: 0.8907 - val_loss: 0.1433 - val_dice_coeff: 0.8567
# Epoch 14/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1092 - dice_coeff: 0.8908
# Epoch 14: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.1092 - dice_coeff: 0.8908 - val_loss: 0.1285 - val_dice_coeff: 0.8715
# Epoch 15/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1054 - dice_coeff: 0.8946
# Epoch 15: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.1054 - dice_coeff: 0.8946 - val_loss: 0.1442 - val_dice_coeff: 0.8558
# Epoch 16/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1033 - dice_coeff: 0.8967
# Epoch 16: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1033 - dice_coeff: 0.8967 - val_loss: 0.1559 - val_dice_coeff: 0.8441
# Epoch 17/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1013 - dice_coeff: 0.8987
# Epoch 17: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.1013 - dice_coeff: 0.8987 - val_loss: 0.1373 - val_dice_coeff: 0.8627
# Epoch 18/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1025 - dice_coeff: 0.8975
# Epoch 18: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.1025 - dice_coeff: 0.8975 - val_loss: 0.1394 - val_dice_coeff: 0.8606
# Epoch 19/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1029 - dice_coeff: 0.8971
# Epoch 19: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1029 - dice_coeff: 0.8971 - val_loss: 0.1364 - val_dice_coeff: 0.8636
# Epoch 20/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1036 - dice_coeff: 0.8964
# Epoch 20: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.1036 - dice_coeff: 0.8964 - val_loss: 0.1216 - val_dice_coeff: 0.8784
# Epoch 21/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0971 - dice_coeff: 0.9029
# Epoch 21: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0971 - dice_coeff: 0.9029 - val_loss: 0.1192 - val_dice_coeff: 0.8808
# Epoch 22/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1007 - dice_coeff: 0.8993
# Epoch 22: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1007 - dice_coeff: 0.8993 - val_loss: 0.1502 - val_dice_coeff: 0.8498
# Epoch 23/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1005 - dice_coeff: 0.8995
# Epoch 23: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.1005 - dice_coeff: 0.8995 - val_loss: 0.1274 - val_dice_coeff: 0.8726
# Epoch 24/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0968 - dice_coeff: 0.9032
# Epoch 24: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0968 - dice_coeff: 0.9032 - val_loss: 0.1658 - val_dice_coeff: 0.8342
# Epoch 25/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1008 - dice_coeff: 0.8992
# Epoch 25: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.1008 - dice_coeff: 0.8992 - val_loss: 0.1406 - val_dice_coeff: 0.8594
# Epoch 26/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0976 - dice_coeff: 0.9024
# Epoch 26: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0976 - dice_coeff: 0.9024 - val_loss: 0.1450 - val_dice_coeff: 0.8550
# Epoch 27/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0998 - dice_coeff: 0.9002
# Epoch 27: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0998 - dice_coeff: 0.9002 - val_loss: 0.1166 - val_dice_coeff: 0.8834
# Epoch 28/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1019 - dice_coeff: 0.8981
# Epoch 28: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.1019 - dice_coeff: 0.8981 - val_loss: 0.1250 - val_dice_coeff: 0.8750
# Epoch 29/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0995 - dice_coeff: 0.9005
# Epoch 29: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0995 - dice_coeff: 0.9005 - val_loss: 0.1214 - val_dice_coeff: 0.8786
# Epoch 30/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0989 - dice_coeff: 0.9011
# Epoch 30: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-4.keras
# ...
# Epoch 34/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0945 - dice_coeff: 0.9055
# Epoch 34: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0945 - dice_coeff: 0.9055 - val_loss: 0.1181 - val_dice_coeff: 0.8819
# Epoch 35/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0962 - dice_coeff: 0.9038
# Epoch 35: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0962 - dice_coeff: 0.9038 - val_loss: 0.1095 - val_dice_coeff: 0.8905
# Epoch 36/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0954 - dice_coeff: 0.9046
# Epoch 36: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0954 - dice_coeff: 0.9046 - val_loss: 0.1090 - val_dice_coeff: 0.8910
# Epoch 37/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0972 - dice_coeff: 0.9028
# Epoch 37: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0972 - dice_coeff: 0.9028 - val_loss: 0.1127 - val_dice_coeff: 0.8873
# Epoch 38/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0989 - dice_coeff: 0.9011
# Epoch 38: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 119s 2s/step - loss: 0.0989 - dice_coeff: 0.9011 - val_loss: 0.1154 - val_dice_coeff: 0.8846
# Epoch 39/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0913 - dice_coeff: 0.9087
# Epoch 39: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0913 - dice_coeff: 0.9087 - val_loss: 0.1198 - val_dice_coeff: 0.8802
# Epoch 40/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0912 - dice_coeff: 0.9088
# Epoch 40: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0912 - dice_coeff: 0.9088 - val_loss: 0.1209 - val_dice_coeff: 0.8791
# Epoch 41/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0927 - dice_coeff: 0.9073
# Epoch 41: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0927 - dice_coeff: 0.9073 - val_loss: 0.1149 - val_dice_coeff: 0.8851
# Epoch 42/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0920 - dice_coeff: 0.9080
# Epoch 42: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 119s 2s/step - loss: 0.0920 - dice_coeff: 0.9080 - val_loss: 0.1132 - val_dice_coeff: 0.8868
# Epoch 43/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0940 - dice_coeff: 0.9060
# Epoch 43: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0940 - dice_coeff: 0.9060 - val_loss: 0.1041 - val_dice_coeff: 0.8959
# Epoch 44/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0934 - dice_coeff: 0.9066
# Epoch 44: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.0934 - dice_coeff: 0.9066 - val_loss: 0.1333 - val_dice_coeff: 0.8667
# Epoch 45/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0925 - dice_coeff: 0.9075
# Epoch 45: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0925 - dice_coeff: 0.9075 - val_loss: 0.1095 - val_dice_coeff: 0.8905
# Epoch 46/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0961 - dice_coeff: 0.9039
# Epoch 46: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 119s 2s/step - loss: 0.0961 - dice_coeff: 0.9039 - val_loss: 0.1373 - val_dice_coeff: 0.8627
# Epoch 47/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0903 - dice_coeff: 0.9097
# Epoch 47: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 105s 1s/step - loss: 0.0903 - dice_coeff: 0.9097 - val_loss: 0.1058 - val_dice_coeff: 0.8942
# Epoch 48/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0939 - dice_coeff: 0.9061
# Epoch 48: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 106s 1s/step - loss: 0.0939 - dice_coeff: 0.9061 - val_loss: 0.1103 - val_dice_coeff: 0.8897
# Epoch 49/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0915 - dice_coeff: 0.9085
# Epoch 49: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0915 - dice_coeff: 0.9085 - val_loss: 0.1063 - val_dice_coeff: 0.8937
# Epoch 50/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0943 - dice_coeff: 0.9057
# Epoch 50: saving model to G:\Harsh_Birva_minor_Proj\new_retina_models_5\restype_16-5.keras
# 75/75 [==============================] - 120s 2s/step - loss: 0.0943 - dice_coeff: 0.9057 - val_loss: 0.1171 - val_dice_coeff: 0.8829
# 1/1 [==============================] - 1s 524ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step

# %%
restype_16 = res_type_16(input_shape = (None,None,None,1))
restype_16.compile(optimizer='adam', loss=dice_coeff_loss, metrics=[dice_coeff])

# %%
history = restype_16.fit(
        train_generator,
        steps_per_epoch=len(df_train) // batch_size,
        epochs=epochs,
        callbacks=[checkpoint],
        validation_data=test_generator,
        validation_steps=len(df_test) // batch_size
    )
# Out:
# Epoch 1/50
# 350/350 [==============================] - ETA: 0s - loss: 0.6201 - dice_coeff: 0.3799
# Epoch 1: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 883s 3s/step - loss: 0.6201 - dice_coeff: 0.3799 - val_loss: 0.3626 - val_dice_coeff: 0.6374
# Epoch 2/50
# 350/350 [==============================] - ETA: 0s - loss: 0.1636 - dice_coeff: 0.8364
# Epoch 2: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 873s 2s/step - loss: 0.1636 - dice_coeff: 0.8364 - val_loss: 0.1312 - val_dice_coeff: 0.8688
# Epoch 3/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0775 - dice_coeff: 0.9225
# Epoch 3: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 867s 2s/step - loss: 0.0775 - dice_coeff: 0.9225 - val_loss: 0.0735 - val_dice_coeff: 0.9265
# Epoch 4/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0577 - dice_coeff: 0.9423
# Epoch 4: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 868s 2s/step - loss: 0.0577 - dice_coeff: 0.9423 - val_loss: 0.0671 - val_dice_coeff: 0.9329
# Epoch 5/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0493 - dice_coeff: 0.9507
# Epoch 5: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 871s 2s/step - loss: 0.0493 - dice_coeff: 0.9507 - val_loss: 0.0742 - val_dice_coeff: 0.9258
# Epoch 6/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0450 - dice_coeff: 0.9550
# Epoch 6: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 870s 2s/step - loss: 0.0450 - dice_coeff: 0.9550 - val_loss: 0.0804 - val_dice_coeff: 0.9196
# Epoch 7/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0450 - dice_coeff: 0.9550
# Epoch 7: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 871s 2s/step - loss: 0.0450 - dice_coeff: 0.9550 - val_loss: 0.0573 - val_dice_coeff: 0.9427
# Epoch 8/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0413 - dice_coeff: 0.9587
# Epoch 8: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 880s 3s/step - loss: 0.0413 - dice_coeff: 0.9587 - val_loss: 0.0457 - val_dice_coeff: 0.9543
# Epoch 9/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0392 - dice_coeff: 0.9608
# Epoch 9: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 874s 2s/step - loss: 0.0392 - dice_coeff: 0.9608 - val_loss: 0.0460 - val_dice_coeff: 0.9540
# Epoch 10/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0377 - dice_coeff: 0.9623
# Epoch 10: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 875s 3s/step - loss: 0.0377 - dice_coeff: 0.9623 - val_loss: 0.0612 - val_dice_coeff: 0.9388
# Epoch 11/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0355 - dice_coeff: 0.9645
# Epoch 11: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 873s 2s/step - loss: 0.0355 - dice_coeff: 0.9645 - val_loss: 0.0578 - val_dice_coeff: 0.9422
# Epoch 12/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0417 - dice_coeff: 0.9583
# Epoch 12: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 874s 2s/step - loss: 0.0417 - dice_coeff: 0.9583 - val_loss: 0.0393 - val_dice_coeff: 0.9607
# Epoch 13/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0370 - dice_coeff: 0.9630
# Epoch 13: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 884s 3s/step - loss: 0.0370 - dice_coeff: 0.9630 - val_loss: 0.0375 - val_dice_coeff: 0.9625
# Epoch 14/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0324 - dice_coeff: 0.9676
# Epoch 14: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 881s 3s/step - loss: 0.0324 - dice_coeff: 0.9676 - val_loss: 0.0599 - val_dice_coeff: 0.9401
# Epoch 15/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0318 - dice_coeff: 0.9682
# Epoch 15: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 869s 2s/step - loss: 0.0318 - dice_coeff: 0.9682 - val_loss: 0.0458 - val_dice_coeff: 0.9542
# Epoch 16/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0304 - dice_coeff: 0.9696
# Epoch 16: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 871s 2s/step - loss: 0.0304 - dice_coeff: 0.9696 - val_loss: 0.0457 - val_dice_coeff: 0.9543
# Epoch 17/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0302 - dice_coeff: 0.9698
# Epoch 17: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 877s 3s/step - loss: 0.0302 - dice_coeff: 0.9698 - val_loss: 0.0472 - val_dice_coeff: 0.9528
# Epoch 18/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0285 - dice_coeff: 0.9715
# Epoch 18: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 885s 3s/step - loss: 0.0285 - dice_coeff: 0.9715 - val_loss: 0.0557 - val_dice_coeff: 0.9443
# Epoch 19/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0296 - dice_coeff: 0.9704
# Epoch 19: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 874s 2s/step - loss: 0.0296 - dice_coeff: 0.9704 - val_loss: 0.0464 - val_dice_coeff: 0.9536
# Epoch 20/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0284 - dice_coeff: 0.9716
# Epoch 20: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 883s 3s/step - loss: 0.0284 - dice_coeff: 0.9716 - val_loss: 0.0530 - val_dice_coeff: 0.9470
# Epoch 21/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0270 - dice_coeff: 0.9730
# Epoch 21: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 877s 3s/step - loss: 0.0270 - dice_coeff: 0.9730 - val_loss: 0.0711 - val_dice_coeff: 0.9289
# Epoch 22/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0267 - dice_coeff: 0.9733
# Epoch 22: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 878s 3s/step - loss: 0.0267 - dice_coeff: 0.9733 - val_loss: 0.0401 - val_dice_coeff: 0.9599
# Epoch 23/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0306 - dice_coeff: 0.9694
# Epoch 23: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 878s 3s/step - loss: 0.0306 - dice_coeff: 0.9694 - val_loss: 0.1364 - val_dice_coeff: 0.8636
# Epoch 24/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0272 - dice_coeff: 0.9728
# Epoch 24: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 878s 3s/step - loss: 0.0272 - dice_coeff: 0.9728 - val_loss: 0.0408 - val_dice_coeff: 0.9592
# Epoch 25/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0242 - dice_coeff: 0.9758
# Epoch 25: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 877s 3s/step - loss: 0.0242 - dice_coeff: 0.9758 - val_loss: 0.0376 - val_dice_coeff: 0.9624
# Epoch 26/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0249 - dice_coeff: 0.9751
# Epoch 26: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 877s 3s/step - loss: 0.0249 - dice_coeff: 0.9751 - val_loss: 0.0432 - val_dice_coeff: 0.9568
# Epoch 27/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0237 - dice_coeff: 0.9763
# Epoch 27: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 883s 3s/step - loss: 0.0237 - dice_coeff: 0.9763 - val_loss: 0.0272 - val_dice_coeff: 0.9728
# Epoch 28/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0240 - dice_coeff: 0.9760
# Epoch 28: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 879s 3s/step - loss: 0.0240 - dice_coeff: 0.9760 - val_loss: 0.0256 - val_dice_coeff: 0.9744
# Epoch 29/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0236 - dice_coeff: 0.9764
# Epoch 29: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 876s 3s/step - loss: 0.0236 - dice_coeff: 0.9764 - val_loss: 0.0450 - val_dice_coeff: 0.9550
# Epoch 30/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0241 - dice_coeff: 0.9759
# Epoch 30: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 878s 3s/step - loss: 0.0241 - dice_coeff: 0.9759 - val_loss: 0.1369 - val_dice_coeff: 0.8631
# Epoch 31/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0256 - dice_coeff: 0.9744
# Epoch 31: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 878s 3s/step - loss: 0.0256 - dice_coeff: 0.9744 - val_loss: 0.0376 - val_dice_coeff: 0.9624
# Epoch 32/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0231 - dice_coeff: 0.9769
# Epoch 32: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 877s 3s/step - loss: 0.0231 - dice_coeff: 0.9769 - val_loss: 0.0620 - val_dice_coeff: 0.9380
# Epoch 33/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0217 - dice_coeff: 0.9783
# Epoch 33: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 878s 3s/step - loss: 0.0217 - dice_coeff: 0.9783 - val_loss: 0.0414 - val_dice_coeff: 0.9586
# Epoch 34/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0223 - dice_coeff: 0.9777
# Epoch 34: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 878s 3s/step - loss: 0.0223 - dice_coeff: 0.9777 - val_loss: 0.0387 - val_dice_coeff: 0.9613
# Epoch 35/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0229 - dice_coeff: 0.9771
# Epoch 35: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 880s 3s/step - loss: 0.0229 - dice_coeff: 0.9771 - val_loss: 0.0428 - val_dice_coeff: 0.9572
# Epoch 36/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0213 - dice_coeff: 0.9787
# Epoch 36: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 879s 3s/step - loss: 0.0213 - dice_coeff: 0.9787 - val_loss: 0.0437 - val_dice_coeff: 0.9563
# Epoch 37/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0216 - dice_coeff: 0.9784
# Epoch 37: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 880s 3s/step - loss: 0.0216 - dice_coeff: 0.9784 - val_loss: 0.0251 - val_dice_coeff: 0.9749
# Epoch 38/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0237 - dice_coeff: 0.9763
# Epoch 38: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 877s 3s/step - loss: 0.0237 - dice_coeff: 0.9763 - val_loss: 0.0366 - val_dice_coeff: 0.9634
# Epoch 39/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0223 - dice_coeff: 0.9777
# Epoch 39: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 874s 2s/step - loss: 0.0223 - dice_coeff: 0.9777 - val_loss: 0.0616 - val_dice_coeff: 0.9384
# Epoch 40/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0228 - dice_coeff: 0.9772
# Epoch 40: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 877s 3s/step - loss: 0.0228 - dice_coeff: 0.9772 - val_loss: 0.0473 - val_dice_coeff: 0.9527
# Epoch 41/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0213 - dice_coeff: 0.9787
# Epoch 41: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 884s 3s/step - loss: 0.0213 - dice_coeff: 0.9787 - val_loss: 0.0498 - val_dice_coeff: 0.9502
# Epoch 42/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0222 - dice_coeff: 0.9778
# Epoch 42: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 877s 3s/step - loss: 0.0222 - dice_coeff: 0.9778 - val_loss: 0.0367 - val_dice_coeff: 0.9633
# Epoch 43/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0207 - dice_coeff: 0.9793
# Epoch 43: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 878s 3s/step - loss: 0.0207 - dice_coeff: 0.9793 - val_loss: 0.0402 - val_dice_coeff: 0.9598
# Epoch 44/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0209 - dice_coeff: 0.9791
# Epoch 44: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 875s 3s/step - loss: 0.0209 - dice_coeff: 0.9791 - val_loss: 0.0470 - val_dice_coeff: 0.9530
# Epoch 45/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0253 - dice_coeff: 0.9747
# Epoch 45: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 876s 3s/step - loss: 0.0253 - dice_coeff: 0.9747 - val_loss: 0.0400 - val_dice_coeff: 0.9600
# Epoch 46/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0221 - dice_coeff: 0.9779
# Epoch 46: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 871s 2s/step - loss: 0.0221 - dice_coeff: 0.9779 - val_loss: 0.0355 - val_dice_coeff: 0.9645
# Epoch 47/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0205 - dice_coeff: 0.9795
# Epoch 47: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 873s 2s/step - loss: 0.0205 - dice_coeff: 0.9795 - val_loss: 0.0455 - val_dice_coeff: 0.9545
# Epoch 48/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0207 - dice_coeff: 0.9793
# Epoch 48: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 870s 2s/step - loss: 0.0207 - dice_coeff: 0.9793 - val_loss: 0.0531 - val_dice_coeff: 0.9469
# Epoch 49/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0204 - dice_coeff: 0.9796
# Epoch 49: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 872s 2s/step - loss: 0.0204 - dice_coeff: 0.9796 - val_loss: 0.0454 - val_dice_coeff: 0.9546
# Epoch 50/50
# 350/350 [==============================] - ETA: 0s - loss: 0.0209 - dice_coeff: 0.9791
# Epoch 50: saving model to F:\Birva_Harsh\Hip_models\restype_8.keras
# 350/350 [==============================] - 874s 2s/step - loss: 0.0209 - dice_coeff: 0.9791 - val_loss: 0.0446 - val_dice_coeff: 0.9554
