# %%
import nrrd
import os
import pandas as pd
import numpy as np
from scipy.ndimage import zoom
import csv
import matplotlib.pyplot as plt
from glob import glob
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model, save_model

# %%
data_path = 'F:\\Birva_Harsh\\NEW_KNEE_CT_100_V1\\Train'

# %%
knee_paths = []
mask_paths = []
csv_paths = []

for folder in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder)
    
    for file in os.listdir(folder_path):
        if file.endswith('.nrrd'):
            if 'segmentation' in file.lower():
                mask_path = os.path.join(folder_path, file)
                mask_paths.append(mask_path)
            else:
                knee_path = os.path.join(folder_path, file)
                knee_paths.append(knee_path)
                
        if file == 'LM_INFO_voxel_Coord_femur.csv':
            csv_path = os.path.join(folder_path, file)
            csv_paths.append(csv_path)

# %%
df_train = pd.DataFrame({'knee': knee_paths, 'mask': mask_paths})

# %%
data_path = 'F:\\Birva_Harsh\\NEW_KNEE_CT_100_V1\\Test'

# %%
knee_paths = []
mask_paths = []
csv_paths_test = []

for folder in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder)
    
    for file in os.listdir(folder_path):
        if file.endswith('.nrrd'):
            if 'segmentation' in file.lower():
                mask_path = os.path.join(folder_path, file)
                mask_paths.append(mask_path)
            else:
                knee_path = os.path.join(folder_path, file)
                knee_paths.append(knee_path)
                
        if file == 'LM_INFO_voxel_Coord_femur.csv':
            csv_path = os.path.join(folder_path, file)
            csv_paths_test.append(csv_path)

# %%
df_test = pd.DataFrame({'knee': knee_paths, 'mask': mask_paths})

# %%
df_test
# Out:
#                                                  knee  \
# 0   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Shobhna...
# 1   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Soma__M...
# 2   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\SUKHBIR...
# 3   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Sumangl...
# 4   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Sumangl...
# 5   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Suman_D...
# 6   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\SUNITA ...
# 7   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\SUSHMA ...
# 8   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Sushma_...
# 9   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Tajinde...
# 10  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Tarwind...
# 11  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Usha_Sa...
# 12  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\VADAMID...
# 13  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Vimal_R...
# 14  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Vimal_R...
# 15  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Vishnu_...
# 16  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Yadav_R...
# 17  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Yadav_R...
# 18  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Yamini_...
# 19  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Zinzuva...
#
#                                                  mask
# 0   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Shobhna...
# 1   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Soma__M...
# 2   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\SUKHBIR...
# 3   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Sumangl...
# 4   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Sumangl...
# 5   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Suman_D...
# 6   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\SUNITA ...
# 7   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\SUSHMA ...
# 8   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Sushma_...
# 9   F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Tajinde...
# 10  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Tarwind...
# 11  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Usha_Sa...
# 12  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\VADAMID...
# 13  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Vimal_R...
# 14  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Vimal_R...
# 15  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Vishnu_...
# 16  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Yadav_R...
# 17  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Yadav_R...
# 18  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Yamini_...
# 19  F:\Birva_Harsh\NEW_KNEE_CT_100_V1\Test\Zinzuva...

# %% [markdown]
# # Preprocessing

# %%
x,y=nrrd.read(df_test.loc[7,'knee'])

# %%
y
# Out:
# OrderedDict([('type', 'int'),
#              ('dimension', 3),
#              ('space', 'left-posterior-superior'),
#              ('sizes', array([512, 512, 817])),
#              ('space directions',
#               array([[0.976562  , 0.        , 0.        ],
#                      [0.        , 0.976562  , 0.        ],
#                      [0.        , 0.        , 0.99999999]])),
#              ('kinds', ['domain', 'domain', 'domain']),
#              ('endian', 'little'),
#              ('encoding', 'gzip'),
#              ('space origin', array([-241.      ,  -80.5     , -877.312988]))])

# %%
def read_csv_to_dict_LM_INFO(csv_file):
    LM_INFO = {}
    with open(csv_file, mode='r') as infile:
        reader = csv.reader(infile)       
        for rows in reader:
            LM_INFO[rows[0]] = np.asarray([float(rows[1]), float(rows[2]), float(rows[3])])
            #print(rows[0], ':', float(rows[1]), float(rows[2]), float(rows[3]))
            
    return LM_INFO

# %%
def zoom_1mm(img,original_space,new_space=[1.0,1.0,1.0]):
    zoom_factor = [original_space[i] / new_space[i] for i in range(3)]
    zoomed_image = zoom(img, zoom_factor, order=0)
    
    return zoomed_image

# %%
def knee_centre(path, original_space):
    KC = read_csv_to_dict_LM_INFO(path)['FKC']
    KC_1mm = [round(original_space[i] * KC[i]) for i in range(3)]
    
    return KC_1mm

# %%
def CROP_3D_CT_IMAGE_AT_GIVEN_POINT_NEW_256(img, centered_at, crop_size):
    crop_size = np.asanyarray(crop_size)
    img = np.pad(img, ((128,128),(128,128),(128,128)),'edge')   

    sp_idx = np.asarray(128+centered_at-crop_size//2,dtype=int)
    ep_idx = np.asarray(128+centered_at+crop_size//2,dtype=int)
       
    return img[sp_idx[0]:ep_idx[0], sp_idx[1]:ep_idx[1], sp_idx[2]:ep_idx[2]]

# %%
def crop_KC(path, csv_path):
    img, info = nrrd.read(path)
    spc_dir = np.diag(info['space directions'])

    img_1mm = zoom_1mm(img, spc_dir)
    KC = knee_centre(csv_paths[i], spc_dir)
    
    info['sizes'] = np.array([256.0,256.0,256.0])
    info['space directions'] = np.eye(3)

# %%
crop_knee_train = 'F:\\Birva_Harsh\\Knee_Crop_Data\\train\\Knee'
crop_mask_train = 'F:\\Birva_Harsh\\Knee_Crop_Data\\train\\Mask'

# %%
for i in range(len(df_train)):
    img, kinfo = nrrd.read(df_train.loc[i,'knee'])
    mask, minfo = nrrd.read(df_train.loc[i,'mask'])
    
    spc_dir = np.diag(kinfo['space directions'])
    
    img_1mm = zoom_1mm(img, spc_dir)
    mask_1mm = zoom_1mm(mask, spc_dir)
    
    KC = knee_centre(csv_paths[i], spc_dir)
    
    kinfo['sizes'] = np.array([256.0,256.0,256.0])
    minfo['sizes'] = np.array([256.0,256.0,256.0])
    kinfo['space directions'] = np.eye(3)
    minfo['space directions'] = np.eye(3)
    
    for j in range(5):
        shift = np.random.randint(-30,30,size=3)
        shift_KC = KC - shift
        
        crop_knee = CROP_3D_CT_IMAGE_AT_GIVEN_POINT_NEW_256(img_1mm, shift_KC, [256,256,256])
        crop_mask = CROP_3D_CT_IMAGE_AT_GIVEN_POINT_NEW_256(mask_1mm, shift_KC, [256,256,256])
        
        output_img_path = os.path.join(crop_knee_train, f"{os.path.basename(os.path.dirname(df_train.loc[i,'knee']))}_{j+1}.nrrd")
        output_mask_path = os.path.join(crop_mask_train, f"{os.path.basename(os.path.dirname(df_train.loc[i,'knee']))}_{j+1}.nrrd")
        
        nrrd.write(output_img_path, crop_knee, kinfo)
        nrrd.write(output_mask_path, crop_mask, minfo)
        
        print(f"{os.path.basename(os.path.dirname(df_train.loc[i,'knee']))}_{j+1}")
# Out:
# Abhijit Banerjeer_1
# Abhijit Banerjeer_2
# Abhijit Banerjeer_3
# Abhijit Banerjeer_4
# Abhijit Banerjeer_5
# Amar_Bahadur_Singh_70_M_1
# Amar_Bahadur_Singh_70_M_2
# Amar_Bahadur_Singh_70_M_3
# Amar_Bahadur_Singh_70_M_4
# Amar_Bahadur_Singh_70_M_5
# AminChand Mehta_1
# AminChand Mehta_2
# AminChand Mehta_3
# AminChand Mehta_4
# AminChand Mehta_5
# Amita_Pandey_62_F_1
# Amita_Pandey_62_F_2
# Amita_Pandey_62_F_3
# Amita_Pandey_62_F_4
# Amita_Pandey_62_F_5
# Anita Chanan_1
# Anita Chanan_2
# Anita Chanan_3
# Anita Chanan_4
# Anita Chanan_5
# Archana_Sawhney_57_F_1
# Archana_Sawhney_57_F_2
# Archana_Sawhney_57_F_3
# Archana_Sawhney_57_F_4
# Archana_Sawhney_57_F_5
# Ashokkumar_Shah_71YM_1
# Ashokkumar_Shah_71YM_2
# Ashokkumar_Shah_71YM_3
# Ashokkumar_Shah_71YM_4
# Ashokkumar_Shah_71YM_5
# Ashutosh_Tiwari_69_M_1
# Ashutosh_Tiwari_69_M_2
# Ashutosh_Tiwari_69_M_3
# Ashutosh_Tiwari_69_M_4
# Ashutosh_Tiwari_69_M_5
# BALA DEVI RT KNEE_1
# BALA DEVI RT KNEE_2
# BALA DEVI RT KNEE_3
# BALA DEVI RT KNEE_4
# BALA DEVI RT KNEE_5
# Balwinder Kaur_1
# Balwinder Kaur_2
# Balwinder Kaur_3
# Balwinder Kaur_4
# Balwinder Kaur_5
# Bani_Nag_70YF_461_1
# Bani_Nag_70YF_461_2
# Bani_Nag_70YF_461_3
# Bani_Nag_70YF_461_4
# Bani_Nag_70YF_461_5
# Bhavnaben_C_Pandya_F68Y_1
# Bhavnaben_C_Pandya_F68Y_2
# Bhavnaben_C_Pandya_F68Y_3
# Bhavnaben_C_Pandya_F68Y_4
# Bhavnaben_C_Pandya_F68Y_5
# BIMLA SHARMA LT KNEE_1
# BIMLA SHARMA LT KNEE_2
# BIMLA SHARMA LT KNEE_3
# BIMLA SHARMA LT KNEE_4
# BIMLA SHARMA LT KNEE_5
# CHANDER KANTA RT KNEE_1
# CHANDER KANTA RT KNEE_2
# CHANDER KANTA RT KNEE_3
# CHANDER KANTA RT KNEE_4
# CHANDER KANTA RT KNEE_5
# DAXABEN OZA LT KNEE_1
# DAXABEN OZA LT KNEE_2
# DAXABEN OZA LT KNEE_3
# DAXABEN OZA LT KNEE_4
# DAXABEN OZA LT KNEE_5
# Devi_Kamla_1
# Devi_Kamla_2
# Devi_Kamla_3
# Devi_Kamla_4
# Devi_Kamla_5
# Devi_Saunla_1
# Devi_Saunla_2
# Devi_Saunla_3
# Devi_Saunla_4
# Devi_Saunla_5
# Divyaben Shah_1
# Divyaben Shah_2
# Divyaben Shah_3
# Divyaben Shah_4
# Divyaben Shah_5
# Durga Sharma_1
# Durga Sharma_2
# Durga Sharma_3
# Durga Sharma_4
# Durga Sharma_5
# Ganesh Kabra_1
# Ganesh Kabra_2
# Ganesh Kabra_3
# Ganesh Kabra_4
# Ganesh Kabra_5
# Ganesh_Kabra_73_M_1
# Ganesh_Kabra_73_M_2
# Ganesh_Kabra_73_M_3
# Ganesh_Kabra_73_M_4
# Ganesh_Kabra_73_M_5
# Geeta Wadhera_1
# Geeta Wadhera_2
# Geeta Wadhera_3
# Geeta Wadhera_4
# Geeta Wadhera_5
# GEETA WADHERA LT KNEE_1
# GEETA WADHERA LT KNEE_2
# GEETA WADHERA LT KNEE_3
# GEETA WADHERA LT KNEE_4
# GEETA WADHERA LT KNEE_5
# Gurbaksh Kaur_1
# Gurbaksh Kaur_2
# Gurbaksh Kaur_3
# Gurbaksh Kaur_4
# Gurbaksh Kaur_5
# Harminder Kaur_1
# Harminder Kaur_2
# Harminder Kaur_3
# Harminder Kaur_4
# Harminder Kaur_5
# Harpreet_Kaur_57_F_1
# Harpreet_Kaur_57_F_2
# Harpreet_Kaur_57_F_3
# Harpreet_Kaur_57_F_4
# Harpreet_Kaur_57_F_5
# HEMABEN RAMATRI LT KNEE_1
# HEMABEN RAMATRI LT KNEE_2
# HEMABEN RAMATRI LT KNEE_3
# HEMABEN RAMATRI LT KNEE_4
# HEMABEN RAMATRI LT KNEE_5
# Hem_Bhatia_63_F_1
# Hem_Bhatia_63_F_2
# Hem_Bhatia_63_F_3
# Hem_Bhatia_63_F_4
# Hem_Bhatia_63_F_5
# Hem_Raj_Sharma_74_M_1
# Hem_Raj_Sharma_74_M_2
# Hem_Raj_Sharma_74_M_3
# Hem_Raj_Sharma_74_M_4
# Hem_Raj_Sharma_74_M_5
# Himadri_Narayan_Chandra lt_1
# Himadri_Narayan_Chandra lt_2
# Himadri_Narayan_Chandra lt_3
# Himadri_Narayan_Chandra lt_4
# Himadri_Narayan_Chandra lt_5
# Indra_Devi_65_F_1
# Indra_Devi_65_F_2
# Indra_Devi_65_F_3
# Indra_Devi_65_F_4
# Indra_Devi_65_F_5
# Jaganath_Sahu_78_M_1
# Jaganath_Sahu_78_M_2
# Jaganath_Sahu_78_M_3
# Jaganath_Sahu_78_M_4
# Jaganath_Sahu_78_M_5
# JAGBIR SINGH RT KNEE_1
# JAGBIR SINGH RT KNEE_2
# JAGBIR SINGH RT KNEE_3
# JAGBIR SINGH RT KNEE_4
# JAGBIR SINGH RT KNEE_5
# JASBIR KAUR LT KNEE_1
# JASBIR KAUR LT KNEE_2
# JASBIR KAUR LT KNEE_3
# JASBIR KAUR LT KNEE_4
# JASBIR KAUR LT KNEE_5
# Kailashbhai Jain_1
# Kailashbhai Jain_2
# Kailashbhai Jain_3
# Kailashbhai Jain_4
# Kailashbhai Jain_5
# Kalparatnashriji_Ms_F70Y_1
# Kalparatnashriji_Ms_F70Y_2
# Kalparatnashriji_Ms_F70Y_3
# Kalparatnashriji_Ms_F70Y_4
# Kalparatnashriji_Ms_F70Y_5
# KIRAN AGARWAL RT KNEE_1
# KIRAN AGARWAL RT KNEE_2
# KIRAN AGARWAL RT KNEE_3
# KIRAN AGARWAL RT KNEE_4
# KIRAN AGARWAL RT KNEE_5
# KIRAN KANDURI LT KNEE_1
# KIRAN KANDURI LT KNEE_2
# KIRAN KANDURI LT KNEE_3
# KIRAN KANDURI LT KNEE_4
# KIRAN KANDURI LT KNEE_5
# Krishna_Kumari_82_F_1
# Krishna_Kumari_82_F_2
# Krishna_Kumari_82_F_3
# Krishna_Kumari_82_F_4
# Krishna_Kumari_82_F_5
# KUNTI PANWAR RT KNEE_1
# KUNTI PANWAR RT KNEE_2
# KUNTI PANWAR RT KNEE_3
# KUNTI PANWAR RT KNEE_4
# KUNTI PANWAR RT KNEE_5
# LILA DEVI LT KNEE_1
# LILA DEVI LT KNEE_2
# LILA DEVI LT KNEE_3
# LILA DEVI LT KNEE_4
# LILA DEVI LT KNEE_5
# LILA DEVI RT KNEE_1
# LILA DEVI RT KNEE_2
# LILA DEVI RT KNEE_3
# LILA DEVI RT KNEE_4
# LILA DEVI RT KNEE_5
# Madhu_Ahuja_F65Y_1
# Madhu_Ahuja_F65Y_2
# Madhu_Ahuja_F65Y_3
# Madhu_Ahuja_F65Y_4
# Madhu_Ahuja_F65Y_5
# Mahendra_Rathod_73YIpdSs_1
# Mahendra_Rathod_73YIpdSs_2
# Mahendra_Rathod_73YIpdSs_3
# Mahendra_Rathod_73YIpdSs_4
# Mahendra_Rathod_73YIpdSs_5
# Mohinder_Pal_Singh_58_M_1
# Mohinder_Pal_Singh_58_M_2
# Mohinder_Pal_Singh_58_M_3
# Mohinder_Pal_Singh_58_M_4
# Mohinder_Pal_Singh_58_M_5
# NARINDER KAUR SAINI LT KNEE_1
# NARINDER KAUR SAINI LT KNEE_2
# NARINDER KAUR SAINI LT KNEE_3
# NARINDER KAUR SAINI LT KNEE_4
# NARINDER KAUR SAINI LT KNEE_5
# Narinder_Kaur_60_F_1
# Narinder_Kaur_60_F_2
# Narinder_Kaur_60_F_3
# Narinder_Kaur_60_F_4
# Narinder_Kaur_60_F_5
# Negi_Bhagat_Singh_1
# Negi_Bhagat_Singh_2
# Negi_Bhagat_Singh_3
# Negi_Bhagat_Singh_4
# Negi_Bhagat_Singh_5
# NIRMALA DEVI LT KNEE_1
# NIRMALA DEVI LT KNEE_2
# NIRMALA DEVI LT KNEE_3
# NIRMALA DEVI LT KNEE_4
# NIRMALA DEVI LT KNEE_5
# Nirmalanem_Kansagra_F56Y_1
# Nirmalanem_Kansagra_F56Y_2
# Nirmalanem_Kansagra_F56Y_3
# Nirmalanem_Kansagra_F56Y_4
# Nirmalanem_Kansagra_F56Y_5
# Nirmal_Kumari_75_F_1
# Nirmal_Kumari_75_F_2
# Nirmal_Kumari_75_F_3
# Nirmal_Kumari_75_F_4
# Nirmal_Kumari_75_F_5
# Niruben_N_Salot_F79Y_1
# Niruben_N_Salot_F79Y_2
# Niruben_N_Salot_F79Y_3
# Niruben_N_Salot_F79Y_4
# Niruben_N_Salot_F79Y_5
# Pawan_Kumar_65_M_1
# Pawan_Kumar_65_M_2
# Pawan_Kumar_65_M_3
# Pawan_Kumar_65_M_4
# Pawan_Kumar_65_M_5
# Rajeshwari__Ghosh_1
# Rajeshwari__Ghosh_2
# Rajeshwari__Ghosh_3
# Rajeshwari__Ghosh_4
# Rajeshwari__Ghosh_5
# Rajpal_Yadav_63_M_1
# Rajpal_Yadav_63_M_2
# Rajpal_Yadav_63_M_3
# Rajpal_Yadav_63_M_4
# Rajpal_Yadav_63_M_5
# RAM KRISHNA MAZARI LT KNEE_1
# RAM KRISHNA MAZARI LT KNEE_2
# RAM KRISHNA MAZARI LT KNEE_3
# RAM KRISHNA MAZARI LT KNEE_4
# RAM KRISHNA MAZARI LT KNEE_5
# RAM KRISHNA MZARI RT KNEE_1
# RAM KRISHNA MZARI RT KNEE_2
# RAM KRISHNA MZARI RT KNEE_3
# RAM KRISHNA MZARI RT KNEE_4
# RAM KRISHNA MZARI RT KNEE_5
# Rameshbhai_J_Patel_M78Y_1
# Rameshbhai_J_Patel_M78Y_2
# Rameshbhai_J_Patel_M78Y_3
# Rameshbhai_J_Patel_M78Y_4
# Rameshbhai_J_Patel_M78Y_5
# RAVI SONI RT KNEE_1
# RAVI SONI RT KNEE_2
# RAVI SONI RT KNEE_3
# RAVI SONI RT KNEE_4
# RAVI SONI RT KNEE_5
# Ravi_Soni_78YAaKl_1
# Ravi_Soni_78YAaKl_2
# Ravi_Soni_78YAaKl_3
# Ravi_Soni_78YAaKl_4
# Ravi_Soni_78YAaKl_5
# Sail_Kumari_Devi_73_F_1
# Sail_Kumari_Devi_73_F_2
# Sail_Kumari_Devi_73_F_3
# Sail_Kumari_Devi_73_F_4
# Sail_Kumari_Devi_73_F_5
# Santosh_Kumati_54_F_1
# Santosh_Kumati_54_F_2
# Santosh_Kumati_54_F_3
# Santosh_Kumati_54_F_4
# Santosh_Kumati_54_F_5
# Sarbjeet_Kaur_41_F_1
# Sarbjeet_Kaur_41_F_2
# Sarbjeet_Kaur_41_F_3
# Sarbjeet_Kaur_41_F_4
# Sarbjeet_Kaur_41_F_5
# Saroj_Bala_62_F_1
# Saroj_Bala_62_F_2
# Saroj_Bala_62_F_3
# Saroj_Bala_62_F_4
# Saroj_Bala_62_F_5
# Shah_Jayshreeben_Pankajbhai_F60_1
# Shah_Jayshreeben_Pankajbhai_F60_2
# Shah_Jayshreeben_Pankajbhai_F60_3
# Shah_Jayshreeben_Pankajbhai_F60_4
# Shah_Jayshreeben_Pankajbhai_F60_5
# Shah_Pushpaben_G_F61Y_1
# Shah_Pushpaben_G_F61Y_2
# Shah_Pushpaben_G_F61Y_3
# Shah_Pushpaben_G_F61Y_4
# Shah_Pushpaben_G_F61Y_5
# SHAMSHUDDIN SHAIKH LT KNEE_1
# SHAMSHUDDIN SHAIKH LT KNEE_2
# SHAMSHUDDIN SHAIKH LT KNEE_3
# SHAMSHUDDIN SHAIKH LT KNEE_4
# SHAMSHUDDIN SHAIKH LT KNEE_5
# Sheelwati_38_F_1
# Sheelwati_38_F_2
# Sheelwati_38_F_3
# Sheelwati_38_F_4
# Sheelwati_38_F_5
# SHIV PRASAD LT KNEE_1
# SHIV PRASAD LT KNEE_2
# SHIV PRASAD LT KNEE_3
# SHIV PRASAD LT KNEE_4
# SHIV PRASAD LT KNEE_5
# Shiv_Kumar_Sharma_71_M_1
# Shiv_Kumar_Sharma_71_M_2
# Shiv_Kumar_Sharma_71_M_3
# Shiv_Kumar_Sharma_71_M_4
# Shiv_Kumar_Sharma_71_M_5

# %%
crop_knee_test = 'F:\\Birva_Harsh\\Knee_Crop_Data\\test\\Knee'
crop_mask_test = 'F:\\Birva_Harsh\\Knee_Crop_Data\\test\\Mask'

# %%
for i in range(len(df_test)):
    img, kinfo = nrrd.read(df_test.loc[i,'knee'])
    mask, minfo = nrrd.read(df_test.loc[i,'mask'])
    
    spc_dir = np.diag(kinfo['space directions'])
    
    img_1mm = zoom_1mm(img, spc_dir)
    mask_1mm = zoom_1mm(mask, spc_dir)
    
    KC = knee_centre(csv_paths_test[i], spc_dir)
    
    kinfo['sizes'] = np.array([256.0,256.0,256.0])
    minfo['sizes'] = np.array([256.0,256.0,256.0])
    kinfo['space directions'] = np.eye(3)
    minfo['space directions'] = np.eye(3)
    
    for j in range(5):
        shift = np.random.randint(-30,30,size=3)
        shift_KC = KC - shift
        
        crop_knee = CROP_3D_CT_IMAGE_AT_GIVEN_POINT_NEW_256(img_1mm, shift_KC, [256,256,256])
        crop_mask = CROP_3D_CT_IMAGE_AT_GIVEN_POINT_NEW_256(mask_1mm, shift_KC, [256,256,256])
        
        output_img_path = os.path.join(crop_knee_test, f"{os.path.basename(os.path.dirname(df_test.loc[i,'knee']))}_{j+1}.nrrd")
        output_mask_path = os.path.join(crop_mask_test, f"{os.path.basename(os.path.dirname(df_test.loc[i,'knee']))}_{j+1}.nrrd")
        
        nrrd.write(output_img_path, crop_knee, kinfo)
        nrrd.write(output_mask_path, crop_mask, minfo)
        
        print(f"{os.path.basename(os.path.dirname(df_test.loc[i,'knee']))}_{j+1}")
# Out:
# Shobhnaben_H_Shah_F74Y_1
# Shobhnaben_H_Shah_F74Y_2
# Shobhnaben_H_Shah_F74Y_3
# Shobhnaben_H_Shah_F74Y_4
# Shobhnaben_H_Shah_F74Y_5
# Soma__Mondal_1
# Soma__Mondal_2
# Soma__Mondal_3
# Soma__Mondal_4
# Soma__Mondal_5
# SUKHBIR KAUR LT KNEE_1
# SUKHBIR KAUR LT KNEE_2
# SUKHBIR KAUR LT KNEE_3
# SUKHBIR KAUR LT KNEE_4
# SUKHBIR KAUR LT KNEE_5
# Sumangla naithani lt_1
# Sumangla naithani lt_2
# Sumangla naithani lt_3
# Sumangla naithani lt_4
# Sumangla naithani lt_5
# Sumangla_Naithani rt_1
# Sumangla_Naithani rt_2
# Sumangla_Naithani rt_3
# Sumangla_Naithani rt_4
# Sumangla_Naithani rt_5
# Suman_Devi_50_F_1
# Suman_Devi_50_F_2
# Suman_Devi_50_F_3
# Suman_Devi_50_F_4
# Suman_Devi_50_F_5
# SUNITA KULAKARNI LT KNEE_1
# SUNITA KULAKARNI LT KNEE_2
# SUNITA KULAKARNI LT KNEE_3
# SUNITA KULAKARNI LT KNEE_4
# SUNITA KULAKARNI LT KNEE_5
# SUSHMA MAGO LT KNEE_1
# SUSHMA MAGO LT KNEE_2
# SUSHMA MAGO LT KNEE_3
# SUSHMA MAGO LT KNEE_4
# SUSHMA MAGO LT KNEE_5
# Sushma_Sharma_82_F_1
# Sushma_Sharma_82_F_2
# Sushma_Sharma_82_F_3
# Sushma_Sharma_82_F_4
# Sushma_Sharma_82_F_5
# Tajinder_Kaur_57_F_1
# Tajinder_Kaur_57_F_2
# Tajinder_Kaur_57_F_3
# Tajinder_Kaur_57_F_4
# Tajinder_Kaur_57_F_5
# Tarwinder_Kaur_68_F_1
# Tarwinder_Kaur_68_F_2
# Tarwinder_Kaur_68_F_3
# Tarwinder_Kaur_68_F_4
# Tarwinder_Kaur_68_F_5
# Usha_Saxena_64_F_1
# Usha_Saxena_64_F_2
# Usha_Saxena_64_F_3
# Usha_Saxena_64_F_4
# Usha_Saxena_64_F_5
# VADAMIDEVI JAIN LT KNEE_1
# VADAMIDEVI JAIN LT KNEE_2
# VADAMIDEVI JAIN LT KNEE_3
# VADAMIDEVI JAIN LT KNEE_4
# VADAMIDEVI JAIN LT KNEE_5
# Vimal_Raka lt_1
# Vimal_Raka lt_2
# Vimal_Raka lt_3
# Vimal_Raka lt_4
# Vimal_Raka lt_5
# Vimal_Raka rt_1
# Vimal_Raka rt_2
# Vimal_Raka rt_3
# Vimal_Raka rt_4
# Vimal_Raka rt_5
# Vishnu_Kant_Bhaghat_62_M_1
# Vishnu_Kant_Bhaghat_62_M_2
# Vishnu_Kant_Bhaghat_62_M_3
# Vishnu_Kant_Bhaghat_62_M_4
# Vishnu_Kant_Bhaghat_62_M_5
# Yadav_Renu lt_1
# Yadav_Renu lt_2
# Yadav_Renu lt_3
# Yadav_Renu lt_4
# Yadav_Renu lt_5
# Yadav_Renu rt_1
# Yadav_Renu rt_2
# Yadav_Renu rt_3
# Yadav_Renu rt_4
# Yadav_Renu rt_5
# Yamini_P_Shah_F69Y_1
# Yamini_P_Shah_F69Y_2
# Yamini_P_Shah_F69Y_3
# Yamini_P_Shah_F69Y_4
# Yamini_P_Shah_F69Y_5
# Zinzuvadia_K_Chimanlal_M78Y_1
# Zinzuvadia_K_Chimanlal_M78Y_2
# Zinzuvadia_K_Chimanlal_M78Y_3
# Zinzuvadia_K_Chimanlal_M78Y_4
# Zinzuvadia_K_Chimanlal_M78Y_5

# %%
def plot_3d(img,mask):
    plt.figure(figsize=(15,8))
    plt.subplot(2, 3, 1)
    plt.imshow(img[128,:,:].T,cmap='gray')
    plt.axis('off')
    plt.title("X")
    
    plt.subplot(2, 3, 2)
    plt.imshow(img[:,128,:].T,cmap='gray')
    plt.axis('off')
    plt.title("Y")
    
    plt.subplot(2, 3, 3)
    plt.imshow(img[:,:,128].T,cmap='gray')
    plt.axis('off')
    plt.title("Z")
    
    
    plt.subplot(2, 3, 4)
    plt.imshow(mask[128,:,:].T,interpolation='nearest')
    plt.axis('off')
    plt.title("Mask X")
    
    plt.subplot(2, 3, 5)
    plt.imshow(mask[:,128,:].T,interpolation='nearest')
    plt.axis('off')
    plt.title("Mask Y")
    
    plt.subplot(2, 3, 6)
    plt.imshow(mask[:,:,128].T,interpolation='nearest')
    plt.axis('off')
    plt.title("Mask Z")
plt.show()

# %%
img, info = nrrd.read(f"G:\Harsh_Birva_minor_Proj\Knee_Crop_Data\Knee\91_2.nrrd")
mask, info = nrrd.read(f"G:\Harsh_Birva_minor_Proj\Knee_Crop_Data\Mask\91_2.nrrd")

# %%
plot_3d(img,mask)

# %%
img, info = nrrd.read("D:\\NEW_KNEE_CT_DATA\\NEW_KNEE_CT_100_V1\\Kalparatnashriji_Ms_F70Y\\5303 lt.nrrd")
mask, minfo = nrrd.read("D:\\NEW_KNEE_CT_DATA\\NEW_KNEE_CT_100_V1\\Kalparatnashriji_Ms_F70Y\\Segmentation.seg.nrrd")

# %%
spc_dir = np.diag(info['space directions'])

# %%
zoom_factor = [spc_dir[i] for i in range(3)]

# %%
img_1mm = zoom(img,spc_dir, order=0)

# %%
img_1mm.shape

# %%
mask_1mm = zoom(mask,spc_dir, order=0)

# %%
KC = knee_centre("D:\\NEW_KNEE_CT_DATA\\NEW_KNEE_CT_100_V1\\Kalparatnashriji_Ms_F70Y\\LM_INFO_voxel_Coord_femur.csv", spc_dir)

# %%
KC = np.array(KC)

# %%
crop_knee = CROP_3D_CT_IMAGE_AT_GIVEN_POINT_NEW_256(img_1mm, KC, [256,256,256])
crop_mask = CROP_3D_CT_IMAGE_AT_GIVEN_POINT_NEW_256(mask_1mm,KC, [256,256,256])

# %%
plot_3d(crop_knee,crop_mask)

# %% [markdown]
# # Training

# %%
knee_files = glob(pathname = crop_knee_path+'\\*')
knee_files[:1]

# %%
mask_files = [path.replace('\\Knee\\', '\\Mask\\') for path in knee_files]
mask_files[:1]

# %%
df_knee = pd.DataFrame( data = {
    'knee': knee_files,
    'mask': mask_files
})

# %%
df_train, df_test = train_test_split(df_knee, random_state=11, test_size=0.205)

# %%
df_train.shape

# %%
df_test.shape

# %%
def load_and_preprocess_image(file_path,resize):
    img,info = nrrd.read(file_path)
    if resize == 128:
        img = img[::2,::2,::2]
    img = np.clip(img, a_min=-1024, a_max=None)
    img = img[:,:,:,np.newaxis]   
    img_scaled = img.astype(np.float32) / 1024.0
    return img_scaled

# %%
def load_and_preprocess_mask(file_path,resize):
    img,info = nrrd.read(file_path)
    if resize == 128:
        img = img[::2,::2,::2]
    
    img_1 = np.where(img == 1, 1, 0)
    img_2 = np.where(img == 2, 1, 0)
    img_3 = np.where(img == 3, 1, 0)
    
    mask = np.stack((img_1, img_2, img_3), axis=-1)
    mask = mask.astype(np.float32)
    return mask

# %%
load_and_preprocess_mask(df_train.loc[0,'mask'],128)

# %%
def generate_data_generator(dataframe,resize, batch_size=1):
    num_samples = len(dataframe)
    while True:
        indices = np.random.randint(0, num_samples, batch_size)
        batch_knee = []
        batch_mask = []
        for idx in indices:
            knee_img = load_and_preprocess_image(dataframe.iloc[idx]['knee'],resize)
            mask_img = load_and_preprocess_mask(dataframe.iloc[idx]['mask'],resize)
            batch_knee.append(knee_img)
            batch_mask.append(mask_img)
        batch_knee = np.array(batch_knee)
        batch_mask = np.array(batch_mask)
        
        yield batch_knee, batch_mask

# %%
batch_size = 1
train_generator = generate_data_generator(df_train, batch_size=batch_size,resize=128)
test_generator = generate_data_generator(df_test, batch_size=batch_size,resize=128)

# %%
def dice_coeff(y_true, y_pred, smooth=100):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)

    intersection = K.sum(y_true_flatten * y_pred_flatten)
    union = K.sum(y_true_flatten) + K.sum(y_pred_flatten)
    return (2 * intersection + smooth) / (union + smooth)

def dice_coeff_loss(y_true, y_pred, smooth=100):
    return 1 - dice_coeff(y_true, y_pred, smooth)

# %%
def encoder_block(inputs, filters):
    conv = Conv3D(filters, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(inputs)
    conv = Conv3D(filters, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(conv)
    x = BatchNormalization()(conv)
    pool = MaxPooling3D(pool_size=(2,2,2), padding="same")(x)
    
    return pool,x

def decoder_block(inputs, filters, x):
    up = Conv3DTranspose(filters, kernel_size=(3,3,3), strides=(2, 2, 2), padding="same", kernel_initializer='he_uniform')(inputs)
    con = concatenate([up, x])
    conv = Conv3D(filters, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(con)
    conv = Conv3D(filters, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(conv)
    x = BatchNormalization()(conv)
    
    return x

# %%
f = 128

# %%
def Pocketnet_32(input_shape = (None, None, None, 1)):
    inputs = Input(input_shape)
    x = Conv3D(filters = f, kernel_size = (3,3,3), padding = 'same', activation = 'relu', kernel_initializer='he_uniform')(inputs)
    x = BatchNormalization()(x)
    
    b1,c1 = encoder_block(inputs, f)
    b2,c2 = encoder_block(b1, f)
    b3,c3 = encoder_block(b2, f)
    b4,c4 = encoder_block(b3, f)

    conv = Conv3D(f, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(b4)
    conv = Conv3D(f, kernel_size = (3,3,3), padding="same", activation = 'relu', kernel_initializer='he_uniform')(conv)

    b4 = decoder_block(conv, f, c4)
    b5 = decoder_block(b4, f, c3)
    b6 = decoder_block(b5, f, c2)
    b7 = decoder_block(b6, f, c1)
    
    outputs = Conv3D(filters = 3, kernel_size = (1,1,1), activation = "sigmoid")(x)
    
    return Model(inputs=[inputs], outputs = [outputs])

# %%
filepath = "G:\\Harsh_Birva_minor_Proj\\Knee_models\\pocketnet_32.keras"

checkpoint = ModelCheckpoint(filepath, 
                             verbose=1 
                             )

# %%
pocket_32 = Pocketnet_32(input_shape = (None,None,None,1))
pocket_32.compile(optimizer='adam', loss=dice_coeff_loss, metrics=[dice_coeff])

# %%
epochs = 50

# %%
history = pocket_32.fit(
        train_generator,
        steps_per_epoch=len(df_train) // batch_size,
        epochs=epochs,
        callbacks=[checkpoint],
        validation_data=test_generator,
        validation_steps=len(df_test) // batch_size
    )

# %%
img_1mm
